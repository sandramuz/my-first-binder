# %%
print("hello")
# Out:
# hello

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [8, 13, 21, 30]

plt.plot(x, y)
plt.show()

# %% [markdown]
# Line Chart Example
# This shows a simple trend between x and y values.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [8, 13, 21, 30]

plt.plot(x, y)
plt.title("Line Chart Example")
plt.show()

# %%
plt.bar(['A', 'B', 'C'], [5, 7, 3])
plt.title("Bar Chart Example")
plt.show()

# %%
plt.scatter([1,2,3,4], [10,20,25,30])
plt.title("Scatter Plot Example")
plt.show()
